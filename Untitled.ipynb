# %%
# import required module
import os
import xml.etree.ElementTree as ET
import spacy
import nltk
import time

#if needed
#nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
# parse the XML document
tree = ET.parse(r"British baby corpus\fic\AB9.xml")
root = tree.getroot()
docsFiles = []

# find the <wtext> element
wtext_element = root.find('.//wtext')

# iterate over the <s> elements and extract the text
for s_element in wtext_element.iter('s'):
    sentence_text = ''
    for w_element in s_element.iter('w'):
        sentence_text += w_element.text + ' '
    #print(sentence_text.strip())
    docsFiles.append(sentence_text.strip())

# %%
print(docsFiles[0])
# Out:
# Detective  Chief  Inspector  John  McLeish  gazed  doubtfully  at  the  plate  before  him

# %%
#Tokenisation
# Splitting each element(each element represent a file) into multiple elements
token =[]
for x in docsFiles:
    token.append(x.split())
    
#print(token)

# %%
#Performing casefold

casefold = []
temp = []

#iterating throught the 2d array and converting each token in a lower case
for x in range(len(token)):
    for t in token[x]:
        temp.append(t.casefold())
        
    casefold.append(temp)
    temp = []

print(casefold[0])
# Out:
# ['detective', 'chief', 'inspector', 'john', 'mcleish', 'gazed', 'doubtfully', 'at', 'the', 'plate', 'before', 'him']

# %%
#Performing stop words removal

stop_words = set(stopwords.words('english'))


stopWordRemoval = []
temp2 = []
 
# iterating through the lower case tokens and removing unimportant words (that are generated and stored in stop_words) 
#like 'a', 'the', etc...
for x in range(len(casefold)):
    for w in casefold[x]:
        if w not in stop_words:
            temp2.append(w)
    
    stopWordRemoval.append(temp2)
    temp2 = []
        
print(stopWordRemoval[0])
# Out:
# ['detective', 'chief', 'inspector', 'john', 'mcleish', 'gazed', 'doubtfully', 'plate']

# %%
#Performing stemming
ps = PorterStemmer()
stemming = []
temp3 = []
    
# iterating through the stopWordRemoval and editing the word into a more general manner for example 'running' to 'run'    
for x in range(len(stopWordRemoval)):
    for w in stopWordRemoval[x]:
        temp3.append(ps.stem(w))
    
    stemming.append(temp3)
    temp3 = []
    
print(stemming[0])
# Out:
# ['detect', 'chief', 'inspector', 'john', 'mcleish', 'gaze', 'doubt', 'plate']

# %%
def build_ngram_counts(text, n):
    ngram_counts = {}
    words = text.split()
    for i in range(len(words)-n+1):
        ngram = ' '.join(words[i:i+n])
        if ngram in ngram_counts:
            ngram_counts[ngram] += 1
        else:
            ngram_counts[ngram] = 1
    return ngram_counts

# %%
start_time = time.time()

my_str = ' '.join([' '.join(lst) for lst in stemming])
#print(my_str)

nGram = build_ngram_counts(my_str, 1)
print(nGram)
end_time = time.time()

print("Time taken: ", end_time - start_time, "seconds")
# Out:
# {'detect': 10, 'chief': 18, 'inspector': 15, 'john': 47, 'mcleish': 302, 'gaze': 11, 'doubt': 5, 'plate': 6, 'thought': 79, 'hungri': 1, 'realiz': 29, 'actual': 15, 'need': 48, 'anyth': 21, 'rather': 32, 'overflow': 1, 'cholesterol': 1, 'canteen': 3, 'new': 33, 'scotland': 14, 'yard': 26, 'provid': 5, 'admir': 8, 'prompt': 2, 'sleep': 9, 'would': 171, 'perhap': 18, 'make': 49, 'sens': 9, 'thirty-six': 4, 'hour': 28, 'straight': 14, 'duti': 6, 'much': 60, 'spent': 10, 'sullen': 2, 'jamaican': 1, 'kill': 17, 'landladi': 1, 'three': 30, 'children': 18, 'crowd': 2, 'kitchen': 10, 'hous': 24, 'behind': 15, 'westway': 2, 'took': 35, 'experiment': 1, 'mouth': 13, 'fri': 2, 'egg': 3, 'wait': 41, 'see': 78, 'go': 150, 'suit': 18, 'progress': 1, 'bake': 2, 'bean': 3, 'cautious': 8, 'finish': 12, 'one': 134, 'sausag': 1, 'decid': 63, 'bread': 1, 'tempt': 1, 'fate': 1, 'push': 16, 'asid': 5, 'reach': 16, 'cup': 15, 'tea': 18, 'rest': 13, 'elbow': 5, 'tabl': 19, 'lift': 12, 'hand': 39, 'weari': 3, 'salut': 1, 'sergeants.': 1, 'dark': 20, 'scot': 3, 'crumpl': 2, 'grey': 5, 'walk': 41, 'counter': 1, 'man': 60, 'alter': 2, 'cours': 57, 'sit': 21, 'opposit': 3, 'goe': 2, 'bruce': 28, 'davidson': 35, 'accompani': 5, 'last': 47, 'post': 3, 'c1': 5, 'divis': 3, 'concern': 6, 'exclus': 3, 'murder': 14, 'work': 58, 'togeth': 19, 'four': 18, 'year': 55, 'cid': 7, 'got': 106, 'tottenham': 2, 'case': 27, 'weigh': 1, 'nae': 3, 'bother': 8, 'hear': 9, "'ve": 79, 'job': 20, 'ye': 67, 'get': 138, 'head': 33, "'re": 39, 'look': 195, 'rough': 5, 'nod': 13, 'glanc': 24, 'washroom': 1, 'mirror': 1, 'reassur': 9, 'sight': 9, 'big': 15, 'six': 13, 'foot': 7, 'inch': 4, 'sock': 2, 'good': 64, 'fourteen': 2, 'stone': 1, 'alway': 24, 'mildli': 4, 'untidi': 6, 'morn': 25, 'worn': 1, 'cloth': 7, 'day': 51, 'half': 12, 'like': 117, 'footbal': 1, 'support': 8, 'night': 15, 'cell': 1, 'thirty-two': 1, 'young': 28, 'enough': 15, 'complet': 6, 'haggard': 1, 'even': 45, 'odd': 5, "'s": 419, 'hair': 26, 'plaster': 1, 'brown': 13, 'eye': 47, 'sunk': 1, 'back': 103, 'redden': 1, 'smoke': 3, 'exhaust': 5, "'m": 62, 'catherin': 110, 'sergeant': 43, 'crane': 51, 'fall': 5, 'asleep': 4, 'amus': 17, 'hope': 27, 'proprietori': 1, 'air': 6, 'join': 11, 'month': 16, 'ago': 22, 'creat': 1, 'major': 4, 'upheav': 1, 'slight': 4, 'woman': 27, 'twenty-seven': 2, 'whose': 4, 'dazzl': 3, 'delic': 1, 'blond': 4, 'conceal': 2, 'feroci': 2, 'intellig': 6, 'attack': 2, 'everi': 21, 'vicin': 1, 'found': 45, 'put': 47, 'best': 15, 'forward': 4, 'done': 24, 'wonder': 19, 'sartori': 1, 'standard': 4, 'notori': 1, 'uncar': 2, 'though': 19, 'unaffect': 1, 'love': 12, 'littl': 26, 'older': 12, 'clever': 8, 'francesca': 83, 'rise': 8, 'star': 4, 'depart': 10, 'trade': 6, 'industri': 3, 'plan': 14, 'celebr': 1, 'thirtieth': 1, 'birthday': 2, 'ski': 3, 'holiday': 7, 'due': 7, 'start': 29, 'two': 52, 'week': 43, "'": 20, 'time': 60, 'smile': 24, 'cheer': 5, 'immeasur': 1, 'plane': 1, 'chat': 3, 'minut': 31, 'longer': 7, 'went': 37, 'offic': 55, 'secretari': 10, 'plumpish': 1, 'infinit': 1, 'compet': 8, 'middle-ag': 2, 'mother': 15, 'phone': 26, 'stood': 17, 'silent': 8, 'fill': 5, 'doorway': 2, 'rais': 9, 'eyebrow': 7, 'motion': 1, 'stay': 8, 'thank': 21, 'jenni': 2, "'ll": 99, 'take': 43, 'said': 121, 'brighten': 2, 'watch': 41, 'jealousi': 5, 'hurri': 7, 'desk': 16, 'darl': 9, 'horrend': 1, 'problem': 9, 'possibl': 25, 'duck': 2, 'coffe': 16, 'caff': 1, 'ten': 21, 'voic': 11, 'end': 22, 'slightli': 10, 'huski': 1, 'clear': 17, 'tristram': 19, 'arrest': 2, 'york': 15, 'better': 28, 'talk': 46, 'oh': 22, 'christ': 4, 'meet': 15, 'rattl': 6, 'much-lov': 1, 'came': 40, 'younger': 10, 'brother': 14, 'eldest': 3, 'child': 9, 'widow': 1, 'consid': 40, 'respons': 9, 'talent': 4, 'musician': 1, 'difficult': 18, 'peopl': 39, 'vari': 2, 'degre': 2, 'twenty-four-year-old': 1, 'twin': 2, 'prove': 3, 'grit': 1, 'teeth': 5, 'tri': 30, 'implic': 2, 'told': 35, 'made': 39, 'quick': 8, 'call': 33, 'across': 16, 'road':  ...
# Time taken:  0.015189170837402344 seconds
